# %%
import json

# Function to load the data
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)
    return data

data = load_data("Ch-4_data.json")


# Display users and their connections
def display_data(data):
    print("Users and their connections:")
    for user in data["users"]:
        print(f"ID:{user['id']} - {user['name']} friends are {user['friends']} and liked pages are {user['liked_pages']}")

    print("\nPages Information:")
    for page in data["pages"]:
        print(f"{page['id']} : {page['name']}")

display_data(data)
# Out:
# Users and their connections:
# ID:1 - Amit friends are [2, 3] and liked pages are [101]
# ID:2 - Priya friends are [1, 4] and liked pages are [102]
# ID:3 - Rahul friends are [1] and liked pages are [101, 103]
# ID:4 - Sara friends are [2] and liked pages are [104]
#
# Pages Information:
# 101 : Python Developers
# 102 : Data Science Enthusiasts
# 103 : AI & ML Community
# 104 : Web Dev Hub
